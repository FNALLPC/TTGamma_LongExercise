# %% [markdown]
# # Running the TTGammaProcessor

# %% [markdown]
# This cell will copy the test files from their location on eos to your local area. This only needs to be done once!

# %%
# %load_ext autoreload
from coffea import util, processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
import numpy as np
import time

# %% [markdown]
# List of samples to be run on (fileset variable) and a dictionary containing the number of events processed for each sample

# %%
fileset = {
    "TTGamma_SingleLept": [
        "root://cmseos.fnal.gov//store/user/cmsdas/2020/long_exercises/TTGamma/TestFiles/TTGamma_1l.root"
    ],
    "TTbarPowheg_Semilept": [
        "root://cmseos.fnal.gov//store/user/cmsdas/2021/long_exercises/TTGamma/TestFiles/TTbar_1l.root"
    ],
    "W4jets": [
        "root://cmseos.fnal.gov//store/user/cmsdas/2022/long_exercises/TTGamma/TestFiles/W4Jets.root"
    ],
    "WGamma_01J_5f": [
        "root://cmseos.fnal.gov//store/user/cmsdas/2023/long_exercises/TTGamma/TestFiles/WGamma.root"
    ],
    "ZGamma_01J_5f_lowMass": [
        "root://cmseos.fnal.gov//store/user/cmsdas/2024/long_exercises/TTGamma/TestFiles/ZGamma.root"
    ],
}

# %% [markdown]
# Run the TTGammaProcessor on the list of files included in fileset.
#
# You can specify the chunksize and maximum number of chunks to process from each sample (selecting a small number of events and one chunk will force coffea to process only a subset of the events for quicker debugging)

# %%
#autoreload forces the kernel to reload the processor to include any new changes
# %autoreload 2
from ttgamma import TTGammaProcessor

tstart = time.time()

#Run Coffea code using uproot
iterative_run = processor.Runner(
    executor = processor.IterativeExecutor(compression=None),
    schema=NanoAODSchema,
    chunksize=40_000,
    maxchunks=1,
)
output = iterative_run(
    fileset,
    treename="Events",
    processor_instance=TTGammaProcessor(isMC=True),
)

elapsed = time.time() - tstart
print("Total time: %.1f seconds"%elapsed)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1654, in Runner._work_function(format, xrootdtimeout, mmap, schema, cache_function, use_dataframes, savemetrics, item, processor_instance)
#    1653 try:
# -> 1654     out = processor_instance.process(events)
#    1655 except Exception as e:
#
# File /srv/ttgamma/processor.py:313, in TTGammaProcessor.process(self, events)
#     311     shift_systs += ["JESUp", "JESDown", "JERUp", "JERDown"]
# --> 313 return processor.accumulate(self.process_shift(events, name) for name in shift_systs)
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/accumulator.py:95, in accumulate(items, accum)
#      94 if accum is None:
# ---> 95     accum = next(gen)
#      96     # we want to produce a new object so that the input is not mutated
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/accumulator.py:92, in <genexpr>(.0)
#      89 def accumulate(
#      90     items: Iterable[Optional[Accumulatable]], accum: Optional[Accumulatable] = None
#      91 ) -> Optional[Accumulatable]:
# ---> 92     gen = (x for x in items if x is not None)
#      93     try:
#
# File /srv/ttgamma/processor.py:313, in <genexpr>(.0)
#     311     shift_systs += ["JESUp", "JESDown", "JERUp", "JERDown"]
# --> 313 return processor.accumulate(self.process_shift(events, name) for name in shift_systs)
#
# File /srv/ttgamma/processor.py:355, in TTGammaProcessor.process_shift(self, events, shift_syst)
#     350 ##################
#     351 # OBJECT SELECTION
#     352 ##################
#     353
#     354 # muon and electron selections are broken out into standalone functions
# --> 355 tightMuons, looseMuons = selectMuons(events)
#     356 tightElectrons, looseElectrons = selectElectrons(events)
#
# File /srv/ttgamma/processor.py:97, in selectMuons(events)
#      87 """Select tight and loose muons
#      88
#      89 Returns a tuple of (tight, loose) muons
#    (...)
#      94 Loose muon requirements are already coded
#      95 """
#      96 muonSelectTight = (
# ---> 97     (events.Muon.pt >= 30)
#      98     & (abs(events.Muon.eta) < 2.4)
#      99     & (events.Muon.tightId)
#     100     & (events.Muon.pfRelIso04_all))  # FIXME 1a
#     102 muonSelectLoose = (
#     103     (events.Muon.pt > 15)
#     104     & (abs(events.Muon.eta) < 2.4)
#    (...)
#     107     & np.invert(muonSelectTight)
#     108 )
#
# File /usr/local/lib/python3.10/site-packages/numpy/lib/mixins.py:21, in _binary_method.<locals>.func(self, other)
#      20     return NotImplemented
# ---> 21 return ufunc(self, other)
#
# File /usr/local/lib/python3.10/site-packages/awkward/highlevel.py:1411, in Array.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1410 if not hasattr(self, "_tracers"):
# -> 1411     return ak._connect._numpy.array_ufunc(ufunc, method, inputs, kwargs)
#    1412 else:
#
# File /usr/local/lib/python3.10/site-packages/awkward/_connect/_numpy.py:250, in array_ufunc(ufunc, method, inputs, kwargs)
#     248     return None
# --> 250 out = ak._util.broadcast_and_apply(
#     251     inputs, getfunction, behavior, allow_records=False, pass_depth=False
#     252 )
#     253 assert isinstance(out, tuple) and len(out) == 1
#
# File /usr/local/lib/python3.10/site-packages/awkward/_util.py:1172, in broadcast_and_apply(inputs, getfunction, behavior, allow_records, pass_depth, pass_user, user, left_broadcast, right_broadcast, numpy_to_regular, regular_to_jagged)
#    1171 isscalar = []
# -> 1172 out = apply(broadcast_pack(inputs, isscalar), 0, user)
#    1173 assert isinstance(out, tuple)
#
# File /usr/local/lib/python3.10/site-packages/awkward/_util.py:925, in broadcast_and_apply.<locals>.apply(inputs, depth, user)
#     923         nextinputs.append(x)
# --> 925 outcontent = apply(nextinputs, depth + 1, user)
#     926 assert isinstance(outcontent, tuple)
#
# File /usr/local/lib/python3.10/site-packages/awkward/_util.py:1028, in broadcast_and_apply.<locals>.apply(inputs, depth, user)
#    1026         nextinputs.append(x)
# -> 1028 outcontent = apply(nextinputs, depth + 1, user)
#    1030 if isinstance(offsets, ak.layout.Index32):
#
# File /usr/local/lib/python3.10/site-packages/awkward/_util.py:753, in broadcast_and_apply.<locals>.apply(inputs, depth, user)
#     752             nextinputs.append(x)
# --> 753     return apply(nextinputs, depth, user)
#     755 elif any(isinstance(x, unknowntypes) for x in inputs):
#
# File /usr/local/lib/python3.10/site-packages/awkward/_util.py:739, in broadcast_and_apply.<locals>.apply(inputs, depth, user)
#     737     args = args + (user,)
# --> 739 custom = getfunction(inputs, *args)
#     740 if callable(custom):
#
# File /usr/local/lib/python3.10/site-packages/awkward/_connect/_numpy.py:195, in array_ufunc.<locals>.getfunction(inputs)
#     194 nplike = ak.nplike.of(*inputs)
# --> 195 result = getattr(ufunc, method)(
#     196     *[nplike.asarray(x) for x in inputs], **kwargs
#     197 )
#     198 return lambda: (ak.operations.convert.from_numpy(result, highlevel=False),)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 14
#       7 #Run Coffea code using uproot
#       8 iterative_run = processor.Runner(
#       9     executor = processor.IterativeExecutor(compression=None),
#      10     schema=NanoAODSchema,
#      11     chunksize=40_000,
#      12     maxchunks=1,
#      13 )
# ---> 14 output = iterative_run(
#      15     fileset,
#      16     treename="Events",
#      17     processor_instance=TTGammaProcessor(isMC=True),
#      18 )
#      20 elapsed = time.time() - tstart
#      21 print("Total time: %.1f seconds"%elapsed)
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1700, in Runner.__call__(self, fileset, treename, processor_instance)
#    1679 def __call__(
#    1680     self,
#    1681     fileset: Dict,
#    1682     treename: str,
#    1683     processor_instance: ProcessorABC,
#    1684 ) -> Accumulatable:
#    1685     """Run the processor_instance on a given fileset
#    1686
#    1687     Parameters
#    (...)
#    1697             An instance of a class deriving from ProcessorABC
#    1698     """
# -> 1700     wrapped_out = self.run(fileset, processor_instance, treename)
#    1701     if self.use_dataframes:
#    1702         return wrapped_out  # not wrapped anymore
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1848, in Runner.run(self, fileset, processor_instance, treename)
#    1843 closure = partial(
#    1844     self.automatic_retries, self.retries, self.skipbadfiles, closure
#    1845 )
#    1847 executor = self.executor.copy(**exe_args)
# -> 1848 wrapped_out, e = executor(chunks, closure, None)
#    1849 if wrapped_out is None:
#    1850     raise ValueError(
#    1851         "No chunks returned results, verify ``processor`` instance structure.\n\
#    1852         if you used skipbadfiles=True, it is possible all your files are bad."
#    1853     )
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:672, in IterativeExecutor.__call__(self, items, function, accumulator)
#     667 with rich_bar() as progress:
#     668     p_id = progress.add_task(
#     669         self.desc, total=len(items), unit=self.unit, disable=not self.status
#     670     )
#     671     return (
# --> 672         accumulate(
#     673             progress.track(
#     674                 map(function, (c for c in items)),
#     675                 total=len(items),
#     676                 task_id=p_id,
#     677             ),
#     678             accumulator,
#     679         ),
#     680         0,
#     681     )
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/accumulator.py:95, in accumulate(items, accum)
#      93 try:
#      94     if accum is None:
# ---> 95         accum = next(gen)
#      96         # we want to produce a new object so that the input is not mutated
#      97         accum = add(accum, next(gen))
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/accumulator.py:92, in <genexpr>(.0)
#      89 def accumulate(
#      90     items: Iterable[Optional[Accumulatable]], accum: Optional[Accumulatable] = None
#      91 ) -> Optional[Accumulatable]:
# ---> 92     gen = (x for x in items if x is not None)
#      93     try:
#      94         if accum is None:
#
# File /usr/local/lib/python3.10/site-packages/rich/progress.py:1215, in Progress.track(self, sequence, total, task_id, description, update_period)
#    1213 advance = self.advance
#    1214 refresh = self.refresh
# -> 1215 for value in sequence:
#    1216     yield value
#    1217     advance(task_id, 1)
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1367, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1361         break
#    1362     if (
#    1363         not skipbadfiles
#    1364         or any("Auth failed" in str(c) for c in chain)
#    1365         or retries == retry_count
#    1366     ):
# -> 1367         raise e
#    1368     warnings.warn("Attempt %d of %d." % (retry_count + 1, retries + 1))
#    1369 retry_count += 1
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1336, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1334 while retry_count <= retries:
#    1335     try:
# -> 1336         return func(*args, **kwargs)
#    1337     # catch xrootd errors and optionally skip
#    1338     # or retry to read the file
#    1339     except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/coffea/processor/executor.py:1656, in Runner._work_function(format, xrootdtimeout, mmap, schema, cache_function, use_dataframes, savemetrics, item, processor_instance)
#    1654     out = processor_instance.process(events)
#    1655 except Exception as e:
# -> 1656     raise Exception(f"Failed processing file: {item!r}") from e
#    1657 if out is None:
#    1658     raise ValueError(
#    1659         "Output of process() should not be None. Make sure your processor's process() function returns an accumulator."
#    1660     )
#
# Exception: Failed processing file: WorkItem(dataset='ZGamma_01J_5f_lowMass', filename='root://cmseos.fnal.gov//store/user/cmsdas/2024/long_exercises/TTGamma/TestFiles/ZGamma.root', treename='Events', entrystart=0, entrystop=41900, fileuuid=b'=\xda\xefF1l\x11\xea\x91\x9fS\xbd\xe1\x83\xbe\xef', usermeta={})

# %%
output

# %%
import hist
import matplotlib.pyplot as plt


fig, ax = plt.subplots()

for ds, histos in output.items():
    h = histos["all_photon_pt"]
    # h = histos["photon_chIso"]
    # for more complex histos you will have to reduce the dimensions with slicing
    # see https://uhi.readthedocs.io/en/latest/indexing.html for a guide
    # h = h[{"category": sum, "lepFlavor": sum, "systematic": "nominal"}]
    h.plot1d(ax=ax, label=ds)

ax.set_yscale("log")
ax.legend()

# %%
expected = util.load("output_Expected.coffea")

hname = "photon_chIso"
for ds, histo in expected.items():
    mine = output[ds][hname].values()
    other = expected[ds][hname].values()
    if mine.shape != other.shape:
        print(f"For dataset {ds} there is a mismatch in axes")
    elif not np.all(mine == other):
        print(f"For dataset {ds} there is a mismatch in bin yields")
    else:
        print(f"All good for {ds}")

print("Done!")

# %% [markdown]
# # Accessing Arrays Interactively

# %% [markdown]
# Below is an example of loading a NanoAOD file interactively. This can be very useful for developing the code, and debugging any issues. Use this area to build your intuition for working with Coffea and awkward arrays!

# %%
import awkward as ak
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

dataset = "TTGamma_SingleLept"
fname = fileset[dataset][0]
events = NanoEventsFactory.from_root(
    fname,
    schemaclass=NanoAODSchema,
    entry_stop=40_000,
    metadata={"dataset": dataset},
).events()

# %% [markdown]
# Once you have opened the file, you can explore its contents using the 'fields' syntax

# %%
events["Photon", "charge"] = 0
leadingMuon = ak.firsts(events.Muon)
leadingPhoton = ak.firsts(events.Photon)
leadingElectron = ak.firsts(events.Electron)

# %%
(leadingMuon + leadingPhoton).mass

# %%
mugammapairs = ak.cartesian({"mu":events.Muon, "gamma":events.Photon})
(mugammapairs.mu + mugammapairs.gamma).mass

# %%
leadingMuon

# %%
print(leadingMuon)

# %%
type(leadingMuon)

# %%
from ttgamma.scalefactors import mu_trig_err

mu_trig_err

# %%
mu_trig_err(1.2, 36)

# %%
events.Photon.matched_gen.fields

# %%
events.GenPart.fields

# %% [markdown]
# There is also a docstring for each of these variables in NanoAOD, which you can access using '?':

# %%
events.Jet.rawFactor?
